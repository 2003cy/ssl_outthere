# %% [markdown]
# # Trainer CLI command

# %%
# !LD_LIBRARY_PATH=/home/yacheng/ssl_outthere/.pixi/envs/h100/lib:$LD_LIBRARY_PATH python trainer.py fit --config low_res_pt.yaml
# Out:
# Seed set to 42
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Converting flux from f_nu (uJy) to f_lambda (∝ f_nu / λ²) (use_jansky=True to disable this conversion)
# grade in (1, 2, 3) filtering: 26486/42196 samples kept
# obs_365_frac > 0.5 filtering: 25072/42196 samples kept
# sn50 >= 1.0 filtering: 19049/42196 samples kept
# z_best > 0.0 filtering: 16711/42196 samples kept
# LowResDataset: 16711 spectra, 473 pixels (0.540–5.515 µm)
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loading `train_dataloader` to estimate number of stepping batches.
#
#   | Name         | Type       | Params | Mode
# ----------------------------------------------------
# 0 | patch_embed  | Linear     | 896    | train
# 1 | stats_embed  | Linear     | 384    | train
# 2 | blocks       | ModuleList | 1.6 M  | train
# 3 | final_ln     | LayerNorm  | 256    | train
# ...
